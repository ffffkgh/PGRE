# %%
import _6_fs_prgds_info_rate
import matplotlib.pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 6,
'burin': 600,
'maxiter': 400,
'seed': 1234
}

model, transition_collection, nglogll_collection = _6_fs_prgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 3.2398 seconds
# sample_h took 12.6829 seconds
# sample_the took 0.0041 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0012 seconds
# sample_g took 0.0045 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0107 seconds
# sample_pi took 0.0570 seconds
# sample_eta took 0.0008 seconds
# Sum over self.A:  tensor(44187)
# sample_A took 20.7356 seconds
# sample_dpgm took 0.1925 seconds
# sample_n took 2.9802 seconds
# sample_h took 11.6861 seconds
# sample_the took 0.0050 seconds
# sample_lam took 0.0006 seconds
# sample_delt took 0.0136 seconds
# sample_g took 0.0047 seconds
# sample_gam took 0.0003 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0130 seconds
# sample_pi took 0.0738 seconds
# sample_eta took 0.0011 seconds
# Sum over self.A:  tensor(15323)
# sample_A took 13.8626 seconds
# sample_dpgm took 0.1672 seconds
# sample_n took 2.9487 seconds
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
import pickle 

with open('icew100_nglogll_matrix_fs_prgds_eps01_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'FS-PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# # iteration: 100 + 200

# %%
# %matplotlib inline
fig, axs = plt.subplots(50, 2, figsize = (16,200))
for i, ax in enumerate(axs.flatten()):
    ax.plot(model.the.T[i])
    ax.set_title('Component {}'.format(i+1))
plt.show()

# %%
# %matplotlib inline
transition_steady = torch.stack(transition_collection) 
transition_mean = torch.mean(transition_steady, axis = 0)
plt.matshow(transition_mean[0], cmap = 'jet')
plt.title(f'Transition Matrix')
# Add colorbar to each subplot
plt.colorbar()
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 55,
'S': 5,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1234
}

model, transition_collection, nglogll_collection = _6_fs_prgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 3.2318 seconds
# sample_h took 7.3420 seconds
# sample_the took 0.0111 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0004 seconds
# sample_g took 0.0029 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0185 seconds
# sample_pi took 0.0376 seconds
# sample_eta took 0.0007 seconds
# Sum over self.A:  tensor(26866)
# sample_A took 11.8220 seconds
# sample_dpgm took 1.1392 seconds
# sample_n took 11.5996 seconds
# sample_h took 22.4496 seconds
# sample_the took 0.0608 seconds
# sample_lam took 0.0235 seconds
# sample_delt took 0.0167 seconds
# sample_g took 0.0147 seconds
# sample_gam took 0.0028 seconds
# sample_beta took 0.0015 seconds
# sample_phi took 0.2766 seconds
# sample_pi took 0.3758 seconds
# sample_eta took 0.0019 seconds
# Sum over self.A:  tensor(10861)
# sample_A took 18.5711 seconds
# sample_dpgm took 0.1026 seconds
# sample_n took 13.2860 seconds
# ...

# %% [markdown]
# K = 50

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS_PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# K = 55

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS_PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
import pickle

with open('icew_nglogll_tensor_fs_prgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS_PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
