# %%
import _8_fs_pgds_info_rate
import matplotlib.pyplot as plt
import numpy as np
import torch
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 6,
'burin': 600,
'maxiter': 400,
'seed': 1234
}

model, transition_collection, nglogll_collection = _8_fs_pgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 2.5877 seconds
# sample_l took 8.9940 seconds
# sample_the took 0.0034 seconds
# sample_delt took 0.0004 seconds
# sample_phi took 0.0103 seconds
# sample_pi took 0.0510 seconds
# sample_eta took 0.0007 seconds
# Sum over self.A:  tensor(21343)
# sample_A took 14.8952 seconds
# sample_dpgm took 0.1554 seconds
# sample_n took 2.4076 seconds
# sample_l took 7.1626 seconds
# sample_the took 0.0057 seconds
# sample_delt took 0.0005 seconds
# sample_phi took 0.0103 seconds
# sample_pi took 0.0569 seconds
# sample_eta took 0.0008 seconds
# Sum over self.A:  tensor(6438)
# sample_A took 11.1416 seconds
# sample_dpgm took 0.1562 seconds
# sample_n took 2.9992 seconds
# sample_l took 6.4222 seconds
# sample_the took 0.0059 seconds
# sample_delt took 0.0005 seconds
# sample_phi took 0.0111 seconds
# sample_pi took 0.0595 seconds
# sample_eta took 0.0009 seconds
# Sum over self.A:  tensor(5071)
# sample_A took 11.6084 seconds
# ...

# %%
import pickle 

with open('icew100_nglogll_matrix_fs_pgds_eps01_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'GS-PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 55,
'S': 5,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1233
}

model, transition_collection, nglogll_collection = _8_fs_pgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 2.5099 seconds
# sample_l took 23.4492 seconds
# sample_the took 0.0227 seconds
# sample_delt took 0.0008 seconds
# sample_phi took 0.2416 seconds
# sample_pi took 0.1951 seconds
# sample_eta took 0.0170 seconds
# Sum over self.A:  tensor(23455)
# sample_A took 23.1647 seconds
# sample_dpgm took 0.1194 seconds
# sample_n took 2.7730 seconds
# sample_l took 6.9113 seconds
# sample_the took 0.0035 seconds
# sample_delt took 0.0003 seconds
# sample_phi took 0.0197 seconds
# sample_pi took 0.0378 seconds
# sample_eta took 0.0007 seconds
# Sum over self.A:  tensor(7676)
# sample_A took 6.4835 seconds
# sample_dpgm took 0.0975 seconds
# sample_n took 2.5007 seconds
# sample_l took 15.9820 seconds
# sample_the took 0.0323 seconds
# sample_delt took 0.0004 seconds
# sample_phi took 0.0766 seconds
# sample_pi took 0.0400 seconds
# sample_eta took 0.0006 seconds
# Sum over self.A:  tensor(7160)
# sample_A took 16.2599 seconds
# ...

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS_PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
with open('icew_nglogll_tensor_fs_pgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %% [markdown]
# K = 55

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS_PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
