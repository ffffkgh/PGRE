# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import _9_nbrgds_info_rate
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 1,
'burin': 600,
'maxiter': 400,
'seed': 2140
}

model, transition_collection, nglogll_collection = _9_nbrgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 1.9250 seconds
# sample_h took 1.0676 seconds
# sample_aux_h took 8.9046 seconds
# sample_the took 0.0052 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0010 seconds
# sample_g took 0.0048 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0114 seconds
# sample_pi took 0.0080 seconds
# sample_n took 2.0983 seconds
# sample_h took 1.0606 seconds
# sample_aux_h took 7.0695 seconds
# sample_the took 0.0049 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0010 seconds
# sample_g took 0.0040 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0116 seconds
# sample_pi took 0.0080 seconds
# sample_n took 2.0162 seconds
# sample_h took 1.0340 seconds
# sample_aux_h took 5.5776 seconds
# sample_the took 0.0057 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0010 seconds
# sample_g took 0.0040 seconds
# ...

# %%
import pickle

with open('icew100_nglogll_mat_nbrgds_eps01_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
import pickle 

with open('nglogll_matrix_nbrgds_eps0_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'GS-PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 50,
'S': 1,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1234
}

model, transition_collection, nglogll_collection = _9_nbrgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 13.1799 seconds
# sample_h took 0.7387 seconds
# sample_aux_h took 15.3552 seconds
# sample_the took 0.0030 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0005 seconds
# sample_g took 0.0029 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0186 seconds
# sample_pi took 0.0056 seconds
# sample_n took 14.0963 seconds
# sample_h took 0.7196 seconds
# sample_aux_h took 15.2125 seconds
# sample_the took 0.0066 seconds
# sample_lam took 0.0006 seconds
# sample_delt took 0.0005 seconds
# sample_g took 0.0047 seconds
# sample_gam took 0.0003 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0283 seconds
# sample_pi took 0.0073 seconds
# sample_n took 13.5398 seconds
# sample_h took 0.7519 seconds
# sample_aux_h took 13.2597 seconds
# sample_the took 0.0034 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0003 seconds
# sample_g took 0.0029 seconds
# ...

# %%
import pickle

with open('icew_nglogll_tensor_nbrgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary $\epsilon_0^{(\theta)}=0$

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary $\epsilon_0^{(\theta)}=0$ K=40

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary, $\epsilon_0^{(\theta)}=0.1$, K=30

# %%
# %matplotlib inline
fig, axs = plt.subplots(15, 2, figsize = (16,48))
for i, ax in enumerate(axs.flatten()):
    ax.plot(model.the.T[i])
    ax.set_title('Component {}'.format(i+1))
plt.show()

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary, $\epsilon_0^{(\theta)}=0.1$, K=80, icews_tensor_reconstruct_3001010.npz

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# unstationary, $\epsilon_0^{(\theta)}=0.1$, K=80, icews_tensor_reconstruct_3001010.npz

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary, $\epsilon_0^{(\theta)}=0.1$, K=70, icews_tensor_reconstruct_3001010.npz

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# unstationary, $\epsilon_0^{(\theta)}=0.1$, K=70, icews_tensor_reconstruct_3001010.npz

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
