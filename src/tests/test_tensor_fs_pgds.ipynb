# %%
from FS_PGDS_Interval_Tensor import FS_PGDS_tensor
from tqdm.auto import tqdm
import torch
# %load_ext Cython
# %load_ext autoreload
# %autoreload 2
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # The easiest situation: deep=1

# %%
V=12
T=300
sys = torch.zeros(T, V)
high_value = 50
low_value = 0
############# Stage 1 #############
sys[0:100, 0:4] = torch.poisson(high_value*torch.ones(100,4))        # 1st community
############# Stage 2 #############
sys[100:200, 4:8] = torch.poisson(high_value*torch.ones(100,4))        # 2st community
############# Stage 3 #############
sys[200:300, 8:12] = torch.poisson(high_value*torch.ones(100,4))        # 3st community

burnin = 60
maxiter = 20
params = {
'tau': 1.,
'alpha0': 10.,
'epsilon_lam': 1.,
'stationary': True
}
params['data'] = sys
params['K'] = 12
params['S'] = 60

fs_pgds = FS_PGDS_tensor(**params)
esti_steady = []
transition_steady = []
# design phi we could get correct estimation of intensity under K=3
fs_pgds.phi[0][:,:] = 0.
fs_pgds.phi[0][0:4,0:4] = 0.25
fs_pgds.phi[0][4:8,4:8] = 0.25
fs_pgds.phi[0][8:12,8:12] = 0.25
fs_pgds.pi  = torch.tile(fs_pgds.phi[0], (params['S'],1,1)) # torch.tile的对象必须是tensor
fs_pgds.pit = torch.tile(fs_pgds.phi[0], (T,1,1))
for iter in tqdm(range(burnin+maxiter)):
    fs_pgds.sample_n()
    fs_pgds.sample_l()
    fs_pgds.sample_the()
    fs_pgds.sample_lam()
    fs_pgds.sample_delt()
    fs_pgds.sample_beta()
    fs_pgds.sample_phi()
    fs_pgds.sample_pi()
    fs_pgds.sample_eta()
    fs_pgds.sample_A()
    fs_pgds.sample_dpgm()

    if iter > burnin:
        esti_temp = fs_pgds.phi[0] @ torch.diag(fs_pgds.lam) @ (fs_pgds.the).T @ torch.diag(fs_pgds.delt)
        esti_steady.append(esti_temp.clone())
        transition_steady.append(fs_pgds.pi.clone())

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
esti_steady = torch.stack(esti_steady)
esti_mean = torch.mean(esti_steady, axis = 0)
fig, axs = plt.subplots(3,4, figsize=(16,9))
for i, ax in enumerate(axs.flatten()):
    ax.plot(sys[:,i], color = 'blue', linewidth = 1, linestyle = '--', label = 'Truth Count')
    ax.plot(esti_mean[i], color = 'red', linewidth = 2, label = 'GS_NBRGDS')
    ax.set_title(f'Dimension:{i+1}')
    ax.set_xlabel('Time:t')
    ax.legend()
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
#transition_steady = torch.stack(transition_steady) 
transition_mean = torch.mean(transition_steady, axis = 0)
fig, axs = plt.subplots(1, 3, figsize=(16, 9))
for i, ax in enumerate(axs.flatten()):
    if i == 0:
        transition_sum = np.sum(np.array(transition_mean)[4:20], axis = 0)
    else:
        transition_sum = np.sum(np.array(transition_mean)[i*20: i*20+20], axis=0)
    im = ax.imshow(transition_sum, cmap='jet')
    ax.set_title(f'Transition Matrix: Stage {i+1}')
    # Add colorbar to each subplot
    cbar = plt.colorbar(im, ax=ax, shrink=0.45)
plt.tight_layout()
plt.show()

# %matplotlib inline
fig, axs = plt.subplots(1,3, figsize = (16,9))
for i in range(3):
    if i == 0:
        ProbAve = torch.mean(fs_pgds.ProbAve[4:20], axis = 0)
    else:
        ProbAve = torch.mean(fs_pgds.ProbAve[i*20:i*20+20], axis = 0) 
    im = axs[i].imshow(torch.log(ProbAve + ProbAve.T + 0.0001), cmap='jet')
    axs[i].set_title(f'Link ProbAve:Stage{i+1}')
    cbar = plt.colorbar(im, ax = axs[i], shrink=0.45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Deep=2, mode 1 = 60, mode 2 = 60, time = 300, interval = 3, community=20*20

# %%
# generate sysnthetic data
T = 300
S = 3
high_value = 10
sys = torch.zeros(T,60,60)
sys[0:100, 0:20, 0:20] = torch.poisson(high_value*torch.ones(100,20,20))
sys[100:200, 20:40, 20:40] = torch.poisson(high_value*torch.ones(100,20,20))
sys[200:300, 40:60, 40:60] = torch.poisson(high_value*torch.ones(100,20,20))

# %%
# run model
burnin = 60
maxiter = 20
params = {
'tau': 0.1,
'alpha0': 10.,
'epsilon_lam': 1.,
'stationary': True,
'data' : sys,
'K' : 30, # latent components
'S' : 60 # sub-stages
}

fs_pgds = FS_PGDS_tensor(**params)
esti_steady = []
transition_steady = []
# phi should be a list
fs_pgds.phi[0][:,:] = 0.
fs_pgds.phi[0][0:20,0:10] = 1/20
fs_pgds.phi[0][20:40,10:20] = 1/20
fs_pgds.phi[0][40:60,20:30] = 1/20
fs_pgds.phi[1][:,:] = 0.
fs_pgds.phi[1][0:20,0:10] = 1/20
fs_pgds.phi[1][20:40,10:20] = 1/20
fs_pgds.phi[1][40:60,20:30] = 1/20

initial_pi = torch.zeros(30,30)
initial_pi[0:10, 0:10] = 1/10
initial_pi[10:20, 10:20] = 1/10
initial_pi[20:30, 20:30] = 1/10
fs_pgds.pi  = torch.tile(initial_pi, (params['S'],1,1)) # torch.tile的对象必须是tensor
fs_pgds.pit = torch.tile(initial_pi, (T,1,1))
for iter in tqdm(range(burnin+maxiter)):
    fs_pgds.sample_n()
    fs_pgds.sample_l()
    fs_pgds.sample_the()
    fs_pgds.sample_lam()
    fs_pgds.sample_delt()
    fs_pgds.sample_beta()
    fs_pgds.sample_phi()
    fs_pgds.sample_pi()
    fs_pgds.sample_eta()
    fs_pgds.sample_A()
    fs_pgds.sample_dpgm()

    if iter > burnin:
        transition_steady.append(fs_pgds.pi.clone())

# %%
# %matplotlib inline
#transition_steady = torch.stack(transition_steady) 
transition_mean = torch.mean(transition_steady, axis = 0)
fig, axs = plt.subplots(1, 3, figsize=(18,6))
for i, ax in enumerate(axs.flatten()):
    if i == 0:
        transition_sum = np.sum(np.array(transition_mean)[4:20], axis = 0)
    else:
        transition_sum = np.sum(np.array(transition_mean)[i*20: i*20+20], axis=0)
    im = ax.imshow(transition_sum, cmap='jet')
    ax.set_title(f'Transition Matrix: Stage {i+1}')
    # Add colorbar to each subplot
    cbar = plt.colorbar(im, ax=ax, shrink=0.45)
plt.tight_layout()
plt.show()

fig, axs = plt.subplots(1,3, figsize = (18,6))
for i in range(3):
    if i == 0:
        ProbAve = torch.mean(fs_pgds.ProbAve[4:20], axis = 0)
    else:
        ProbAve = torch.mean(fs_pgds.ProbAve[i*20:i*20+20], axis = 0) 
    im = axs[i].imshow(torch.log(ProbAve + ProbAve.T + 0.01), cmap='jet')
    axs[i].set_title(f'Link ProbAve:Stage{i+1}')
    cbar = plt.colorbar(im, ax = axs[i], shrink=0.45)
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
fig, axs = plt.subplots(1,3, figsize = (16,9))
for i in range(3):
    if i == 0:
        dpgm_phi = torch.sum(fs_pgds.fs_dpgm_model.phi[4:20], axis = 0)
    else:
        dpgm_phi = torch.sum(fs_pgds.fs_dpgm_model.phi[i*20:i*20+20], axis = 0) 
    latent_feature = torch.log(dpgm_phi @ fs_pgds.fs_dpgm_model.lam_kk + 0.01)
    im = axs[i].imshow(latent_feature, cmap='jet')
    axs[i].set_title(f'M_skc:Interval {i+1}')
    cbar = plt.colorbar(im, ax = axs[i], shrink=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# Set sub-stages S=3

# %%
# run model
burnin = 60
maxiter = 20
params = {
'tau': 0.1,
'alpha0': 10.,
'epsilon_lam': 1.,
'stationary': True,
'data' : sys,
'K' : 30, # latent components
'S' : 3 # sub-stages
}

fs_pgds = FS_PGDS_tensor(**params)
esti_steady = []
transition_steady = []
# phi should be a list
fs_pgds.phi[0][:,:] = 0.
fs_pgds.phi[0][0:20,0:10] = 1/20
fs_pgds.phi[0][20:40,10:20] = 1/20
fs_pgds.phi[0][40:60,20:30] = 1/20
fs_pgds.phi[1][:,:] = 0.
fs_pgds.phi[1][0:20,0:10] = 1/20
fs_pgds.phi[1][20:40,10:20] = 1/20
fs_pgds.phi[1][40:60,20:30] = 1/20

initial_pi = torch.zeros(30,30)
initial_pi[0:10, 0:10] = 1/10
initial_pi[10:20, 10:20] = 1/10
initial_pi[20:30, 20:30] = 1/10
fs_pgds.pi  = torch.tile(initial_pi, (params['S'],1,1)) # torch.tile的对象必须是tensor
fs_pgds.pit = torch.tile(initial_pi, (T,1,1))
for iter in tqdm(range(burnin+maxiter)):
    fs_pgds.sample_n()
    fs_pgds.sample_l()
    fs_pgds.sample_the()
    fs_pgds.sample_lam()
    fs_pgds.sample_delt()
    fs_pgds.sample_beta()
    fs_pgds.sample_phi()
    fs_pgds.sample_pi()
    fs_pgds.sample_eta()
    fs_pgds.sample_A()
    fs_pgds.sample_dpgm()

    if iter > burnin:
        transition_steady.append(fs_pgds.pi.clone())
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# sample_n took 50.4025 seconds
# sample_l took 3.0902 seconds
# sample_the took 0.0111 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0701 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0006 seconds
# tensor(2989)
# sample_A took 0.8871 seconds
# sample_dpgm took 0.0241 seconds
# sample_n took 50.3805 seconds
# sample_l took 2.9734 seconds
# sample_the took 0.0101 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0023 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0612 seconds
# sample_pi took 0.0095 seconds
# sample_eta took 0.0005 seconds
# tensor(9200)
# sample_A took 0.8604 seconds
# sample_dpgm took 0.0305 seconds
# sample_n took 49.9487 seconds
# sample_l took 3.5925 seconds
# sample_the took 0.0106 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0649 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(25709)
# sample_A took 1.2383 seconds
# sample_dpgm took 0.0440 seconds
# sample_n took 49.6439 seconds
# sample_l took 3.5663 seconds
# sample_the took 0.0118 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0663 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(25239)
# sample_A took 1.1463 seconds
# sample_dpgm took 0.0483 seconds
# sample_n took 50.1850 seconds
# sample_l took 3.6253 seconds
# sample_the took 0.0102 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0029 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0770 seconds
# sample_pi took 0.0104 seconds
# sample_eta took 0.0005 seconds
# tensor(24654)
# sample_A took 1.1971 seconds
# sample_dpgm took 0.0546 seconds
# sample_n took 50.4454 seconds
# sample_l took 3.3500 seconds
# sample_the took 0.0106 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0682 seconds
# sample_pi took 0.0118 seconds
# sample_eta took 0.0005 seconds
# tensor(23313)
# sample_A took 1.1050 seconds
# sample_dpgm took 0.0498 seconds
# sample_n took 49.2213 seconds
# sample_l took 3.3549 seconds
# sample_the took 0.0113 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0654 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(23784)
# sample_A took 1.1126 seconds
# sample_dpgm took 0.0574 seconds
# sample_n took 49.3120 seconds
# sample_l took 3.2700 seconds
# sample_the took 0.0096 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0019 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0647 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(22301)
# sample_A took 1.1048 seconds
# sample_dpgm took 0.0584 seconds
# sample_n took 49.1355 seconds
# sample_l took 3.2167 seconds
# sample_the took 0.0092 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0731 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(23865)
# sample_A took 1.0269 seconds
# sample_dpgm took 0.0634 seconds
# sample_n took 49.2139 seconds
# sample_l took 3.2009 seconds
# sample_the took 0.0101 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0023 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0673 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(23199)
# sample_A took 0.9767 seconds
# sample_dpgm took 0.0782 seconds
# sample_n took 49.2848 seconds
# sample_l took 3.1944 seconds
# sample_the took 0.0096 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0731 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(19685)
# sample_A took 0.9560 seconds
# sample_dpgm took 0.0674 seconds
# sample_n took 49.9086 seconds
# sample_l took 3.2347 seconds
# sample_the took 0.0106 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0691 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(21310)
# sample_A took 0.9886 seconds
# sample_dpgm took 0.1119 seconds
# sample_n took 49.6847 seconds
# sample_l took 3.2900 seconds
# sample_the took 0.0107 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0783 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(13670)
# sample_A took 0.9458 seconds
# sample_dpgm took 0.0456 seconds
# sample_n took 50.7202 seconds
# sample_l took 3.3294 seconds
# sample_the took 0.0121 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0027 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0637 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0006 seconds
# tensor(14165)
# sample_A took 0.9472 seconds
# sample_dpgm took 0.0472 seconds
# sample_n took 49.9694 seconds
# sample_l took 3.5447 seconds
# sample_the took 0.0095 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0031 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0760 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(17342)
# sample_A took 0.9669 seconds
# sample_dpgm took 0.1052 seconds
# sample_n took 48.9226 seconds
# sample_l took 3.7158 seconds
# sample_the took 0.0093 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0019 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0770 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(18222)
# sample_A took 0.9635 seconds
# sample_dpgm took 0.0825 seconds
# sample_n took 49.2372 seconds
# sample_l took 3.5443 seconds
# sample_the took 0.0109 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0729 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(14083)
# sample_A took 0.9375 seconds
# sample_dpgm took 0.0490 seconds
# sample_n took 48.6503 seconds
# sample_l took 3.5587 seconds
# sample_the took 0.0093 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0019 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0691 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(12363)
# sample_A took 0.9335 seconds
# sample_dpgm took 0.0384 seconds
# sample_n took 48.6819 seconds
# sample_l took 3.5468 seconds
# sample_the took 0.0094 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0774 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(21552)
# sample_A took 0.9310 seconds
# sample_dpgm took 0.0753 seconds
# sample_n took 49.3941 seconds
# sample_l took 3.6222 seconds
# sample_the took 0.0104 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0030 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0774 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(12372)
# sample_A took 0.9036 seconds
# sample_dpgm took 0.0518 seconds
# sample_n took 49.2938 seconds
# sample_l took 3.5909 seconds
# sample_the took 0.0099 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0750 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(15423)
# sample_A took 0.9214 seconds
# sample_dpgm took 0.0529 seconds
# sample_n took 49.1627 seconds
# sample_l took 3.6042 seconds
# sample_the took 0.0098 seconds
# sample_lam took 0.0003 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0757 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(15647)
# sample_A took 0.9353 seconds
# sample_dpgm took 0.0503 seconds
# sample_n took 48.9887 seconds
# sample_l took 3.7779 seconds
# sample_the took 0.0096 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0023 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0775 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(20151)
# sample_A took 0.9564 seconds
# sample_dpgm took 0.0942 seconds
# sample_n took 49.1032 seconds
# sample_l took 3.5945 seconds
# sample_the took 0.0092 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0793 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(15155)
# sample_A took 0.8743 seconds
# sample_dpgm took 0.0453 seconds
# sample_n took 50.5400 seconds
# sample_l took 3.5937 seconds
# sample_the took 0.0169 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0266 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0724 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16188)
# sample_A took 0.9116 seconds
# sample_dpgm took 0.0461 seconds
# sample_n took 50.0264 seconds
# sample_l took 3.5828 seconds
# sample_the took 0.0108 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0023 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0717 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(17970)
# sample_A took 0.9416 seconds
# sample_dpgm took 0.0488 seconds
# sample_n took 50.2079 seconds
# sample_l took 3.6631 seconds
# sample_the took 0.0104 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0725 seconds
# sample_pi took 0.0105 seconds
# sample_eta took 0.0005 seconds
# tensor(16884)
# sample_A took 0.8939 seconds
# sample_dpgm took 0.0529 seconds
# sample_n took 49.8106 seconds
# sample_l took 3.6046 seconds
# sample_the took 0.0090 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0760 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16558)
# sample_A took 0.8945 seconds
# sample_dpgm took 0.0471 seconds
# sample_n took 49.5567 seconds
# sample_l took 3.6694 seconds
# sample_the took 0.0115 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0029 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0728 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16119)
# sample_A took 0.9212 seconds
# sample_dpgm took 0.0443 seconds
# sample_n took 49.9882 seconds
# sample_l took 3.6476 seconds
# sample_the took 0.0104 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0025 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0754 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16850)
# sample_A took 0.9399 seconds
# sample_dpgm took 0.0464 seconds
# sample_n took 50.2549 seconds
# sample_l took 3.6146 seconds
# sample_the took 0.0101 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0794 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(17262)
# sample_A took 0.9300 seconds
# sample_dpgm took 0.0479 seconds
# sample_n took 49.9208 seconds
# sample_l took 3.5056 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0710 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(22056)
# sample_A took 0.9106 seconds
# sample_dpgm took 0.0735 seconds
# sample_n took 50.3796 seconds
# sample_l took 3.6859 seconds
# sample_the took 0.0102 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0729 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(14732)
# sample_A took 0.8845 seconds
# sample_dpgm took 0.0475 seconds
# sample_n took 50.5015 seconds
# sample_l took 3.6804 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0031 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0789 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0006 seconds
# tensor(16073)
# sample_A took 0.9260 seconds
# sample_dpgm took 0.0544 seconds
# sample_n took 51.5431 seconds
# sample_l took 3.6350 seconds
# sample_the took 0.0129 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0273 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0870 seconds
# sample_pi took 0.0252 seconds
# sample_eta took 0.0006 seconds
# tensor(17304)
# sample_A took 0.9490 seconds
# sample_dpgm took 0.0676 seconds
# sample_n took 50.6093 seconds
# sample_l took 3.6528 seconds
# sample_the took 0.0138 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0779 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(28493)
# sample_A took 0.9471 seconds
# sample_dpgm took 0.1381 seconds
# sample_n took 50.6724 seconds
# sample_l took 3.5798 seconds
# sample_the took 0.0121 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0284 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0871 seconds
# sample_pi took 0.0379 seconds
# sample_eta took 0.0006 seconds
# tensor(14241)
# sample_A took 0.9340 seconds
# sample_dpgm took 0.0441 seconds
# sample_n took 50.0344 seconds
# sample_l took 3.7097 seconds
# sample_the took 0.0115 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0804 seconds
# sample_pi took 0.0110 seconds
# sample_eta took 0.0005 seconds
# tensor(16731)
# sample_A took 0.9515 seconds
# sample_dpgm took 0.0540 seconds
# sample_n took 51.1720 seconds
# sample_l took 3.6917 seconds
# sample_the took 0.0095 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0801 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16444)
# sample_A took 0.9658 seconds
# sample_dpgm took 0.0487 seconds
# sample_n took 50.2806 seconds
# sample_l took 3.8191 seconds
# sample_the took 0.0116 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0765 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16050)
# sample_A took 0.9085 seconds
# sample_dpgm took 0.0498 seconds
# sample_n took 50.0293 seconds
# sample_l took 3.7179 seconds
# sample_the took 0.0110 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0733 seconds
# sample_pi took 0.0108 seconds
# sample_eta took 0.0005 seconds
# tensor(17177)
# sample_A took 0.9502 seconds
# sample_dpgm took 0.0581 seconds
# sample_n took 52.1452 seconds
# sample_l took 3.8589 seconds
# sample_the took 0.0115 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0027 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0799 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(17902)
# sample_A took 0.9852 seconds
# sample_dpgm took 0.0694 seconds
# sample_n took 51.0466 seconds
# sample_l took 3.9311 seconds
# sample_the took 0.0125 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0762 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(19474)
# sample_A took 0.9863 seconds
# sample_dpgm took 0.0541 seconds
# sample_n took 51.0226 seconds
# sample_l took 3.7393 seconds
# sample_the took 0.0104 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0800 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(20151)
# sample_A took 0.9820 seconds
# sample_dpgm took 0.0576 seconds
# sample_n took 50.8214 seconds
# sample_l took 3.7176 seconds
# sample_the took 0.0110 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0797 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(21067)
# sample_A took 0.9760 seconds
# sample_dpgm took 0.0599 seconds
# sample_n took 50.9031 seconds
# sample_l took 3.7029 seconds
# sample_the took 0.0109 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0786 seconds
# sample_pi took 0.0096 seconds
# sample_eta took 0.0005 seconds
# tensor(20877)
# sample_A took 0.9551 seconds
# sample_dpgm took 0.0621 seconds
# sample_n took 50.4579 seconds
# sample_l took 3.6341 seconds
# sample_the took 0.0099 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0652 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(21830)
# sample_A took 0.9484 seconds
# sample_dpgm took 0.0592 seconds
# sample_n took 50.2069 seconds
# sample_l took 3.6735 seconds
# sample_the took 0.0108 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0731 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(25847)
# sample_A took 0.9529 seconds
# sample_dpgm took 0.0864 seconds
# sample_n took 50.4980 seconds
# sample_l took 3.7121 seconds
# sample_the took 0.0102 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0693 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(16609)
# sample_A took 0.9323 seconds
# sample_dpgm took 0.0532 seconds
# sample_n took 51.5622 seconds
# sample_l took 3.7575 seconds
# sample_the took 0.0122 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0028 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0655 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(19668)
# sample_A took 0.9751 seconds
# sample_dpgm took 0.0709 seconds
# sample_n took 50.8468 seconds
# sample_l took 3.8702 seconds
# sample_the took 0.0139 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0033 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0529 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0006 seconds
# tensor(15211)
# sample_A took 0.9357 seconds
# sample_dpgm took 0.0492 seconds
# sample_n took 51.5068 seconds
# sample_l took 3.7238 seconds
# sample_the took 0.0112 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0804 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(13416)
# sample_A took 0.9446 seconds
# sample_dpgm took 0.0495 seconds
# sample_n took 50.9217 seconds
# sample_l took 3.7407 seconds
# sample_the took 0.0106 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0071 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0788 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(14794)
# sample_A took 0.9574 seconds
# sample_dpgm took 0.0496 seconds
# sample_n took 50.8608 seconds
# sample_l took 3.7439 seconds
# sample_the took 0.0100 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0737 seconds
# sample_pi took 0.0105 seconds
# sample_eta took 0.0005 seconds
# tensor(18450)
# sample_A took 0.9636 seconds
# sample_dpgm took 0.0562 seconds
# sample_n took 50.5088 seconds
# sample_l took 3.6870 seconds
# sample_the took 0.0109 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0812 seconds
# sample_pi took 0.0105 seconds
# sample_eta took 0.0005 seconds
# tensor(17673)
# sample_A took 0.9666 seconds
# sample_dpgm took 0.0678 seconds
# sample_n took 51.0540 seconds
# sample_l took 3.7850 seconds
# sample_the took 0.0107 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0728 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16655)
# sample_A took 0.9488 seconds
# sample_dpgm took 0.0572 seconds
# sample_n took 51.1123 seconds
# sample_l took 3.6551 seconds
# sample_the took 0.0111 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0024 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0687 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16836)
# sample_A took 0.9339 seconds
# sample_dpgm took 0.0560 seconds
# sample_n took 50.9565 seconds
# sample_l took 3.7024 seconds
# sample_the took 0.0095 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0024 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0750 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(18278)
# sample_A took 0.8864 seconds
# sample_dpgm took 0.0625 seconds
# sample_n took 50.8604 seconds
# sample_l took 3.7658 seconds
# sample_the took 0.0128 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0253 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0849 seconds
# sample_pi took 0.0291 seconds
# sample_eta took 0.0005 seconds
# tensor(21259)
# sample_A took 0.9411 seconds
# sample_dpgm took 0.0718 seconds
# sample_n took 50.7185 seconds
# sample_l took 3.6673 seconds
# sample_the took 0.0105 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0726 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(19581)
# sample_A took 0.8559 seconds
# sample_dpgm took 0.0741 seconds
# sample_n took 50.3286 seconds
# sample_l took 3.6206 seconds
# sample_the took 0.0108 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0733 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(18550)
# sample_A took 0.8540 seconds
# sample_dpgm took 0.0634 seconds
# sample_n took 50.3282 seconds
# sample_l took 3.5971 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0718 seconds
# sample_pi took 0.0114 seconds
# sample_eta took 0.0005 seconds
# tensor(18378)
# sample_A took 0.8597 seconds
# sample_dpgm took 0.0686 seconds
# sample_n took 50.4827 seconds
# sample_l took 3.8178 seconds
# sample_the took 0.0117 seconds
# sample_lam took 0.0003 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0666 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(16863)
# sample_A took 0.8595 seconds
# sample_dpgm took 0.0587 seconds
# sample_n took 51.1225 seconds
# sample_l took 3.6280 seconds
# sample_the took 0.0114 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0264 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0706 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(14012)
# sample_A took 0.8510 seconds
# sample_dpgm took 0.0627 seconds
# sample_n took 50.6340 seconds
# sample_l took 3.5157 seconds
# sample_the took 0.0114 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0745 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(16027)
# sample_A took 0.8778 seconds
# sample_dpgm took 0.0545 seconds
# sample_n took 49.9025 seconds
# sample_l took 3.4967 seconds
# sample_the took 0.0027 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0720 seconds
# sample_pi took 0.0108 seconds
# sample_eta took 0.0005 seconds
# tensor(23224)
# sample_A took 0.8911 seconds
# sample_dpgm took 0.0761 seconds
# sample_n took 49.5632 seconds
# sample_l took 3.4430 seconds
# sample_the took 0.0105 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0027 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0608 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(14227)
# sample_A took 0.8548 seconds
# sample_dpgm took 0.0591 seconds
# sample_n took 50.6674 seconds
# sample_l took 3.5420 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0746 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(14360)
# sample_A took 0.8588 seconds
# sample_dpgm took 0.0547 seconds
# sample_n took 50.4405 seconds
# sample_l took 3.6003 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0752 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(12228)
# sample_A took 0.8553 seconds
# sample_dpgm took 0.0525 seconds
# sample_n took 50.5721 seconds
# sample_l took 3.4600 seconds
# sample_the took 0.0101 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0625 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(14192)
# sample_A took 0.8439 seconds
# sample_dpgm took 0.0564 seconds
# sample_n took 49.9166 seconds
# sample_l took 3.5002 seconds
# sample_the took 0.0103 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0023 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0754 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(11812)
# sample_A took 0.8154 seconds
# sample_dpgm took 0.0597 seconds
# sample_n took 49.8037 seconds
# sample_l took 3.3559 seconds
# sample_the took 0.0106 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0745 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(10359)
# sample_A took 1.4029 seconds
# sample_dpgm took 0.0774 seconds
# sample_n took 50.0509 seconds
# sample_l took 3.3775 seconds
# sample_the took 0.0109 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0035 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0757 seconds
# sample_pi took 0.0107 seconds
# sample_eta took 0.0005 seconds
# tensor(10264)
# sample_A took 0.8525 seconds
# sample_dpgm took 0.0453 seconds
# sample_n took 50.0491 seconds
# sample_l took 3.2849 seconds
# sample_the took 0.0109 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0022 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0699 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(10443)
# sample_A took 0.8330 seconds
# sample_dpgm took 0.0483 seconds
# sample_n took 49.8797 seconds
# sample_l took 3.1764 seconds
# sample_the took 0.0113 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0743 seconds
# sample_pi took 0.0189 seconds
# sample_eta took 0.0008 seconds
# tensor(14165)
# sample_A took 0.8500 seconds
# sample_dpgm took 0.0572 seconds
# sample_n took 49.7052 seconds
# sample_l took 3.2404 seconds
# sample_the took 0.0102 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0692 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(8551)
# sample_A took 0.7776 seconds
# sample_dpgm took 0.0439 seconds
# sample_n took 50.3667 seconds
# sample_l took 3.2934 seconds
# sample_the took 0.0093 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0661 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(7354)
# sample_A took 0.7587 seconds
# sample_dpgm took 0.0366 seconds
# sample_n took 48.8364 seconds
# sample_l took 3.2495 seconds
# sample_the took 0.0092 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0746 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(6571)
# sample_A took 0.7607 seconds
# sample_dpgm took 0.0357 seconds
# sample_n took 48.6408 seconds
# sample_l took 3.1558 seconds
# sample_the took 0.0100 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0021 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0751 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(7428)
# sample_A took 0.7847 seconds
# sample_dpgm took 0.0355 seconds
# sample_n took 48.6174 seconds
# sample_l took 3.0748 seconds
# sample_the took 0.0095 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0020 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0718 seconds
# sample_pi took 0.0106 seconds
# sample_eta took 0.0005 seconds
# tensor(8577)
# sample_A took 0.7395 seconds
# sample_dpgm took 0.0389 seconds

# %%
# %matplotlib inline
#transition_steady = torch.stack(transition_steady) 
transition_mean = torch.mean(transition_steady, axis = 0)
fig, axs = plt.subplots(1, 3, figsize=(18,6))
for i, ax in enumerate(axs.flatten()):
    transition_sum = np.array(transition_mean)[i]
    im = ax.imshow(transition_sum, cmap='jet')
    ax.set_title(f'Transition Matrix: Stage {i+1}')
    # Add colorbar to each subplot
    cbar = plt.colorbar(im, ax=ax, shrink=0.45)
plt.tight_layout()
plt.show()

fig, axs = plt.subplots(1,3, figsize = (18,6))
for i in range(3):
    ProbAve = fs_pgds.ProbAve[i]
    im = axs[i].imshow(torch.log(ProbAve + ProbAve.T + 0.01), cmap='jet')
    axs[i].set_title(f'Link ProbAve:Stage{i+1}')
    cbar = plt.colorbar(im, ax = axs[i], shrink=0.45)
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
fig, axs = plt.subplots(1,3, figsize = (16,9))
for i in range(3):
    dpgm_phi = fs_pgds.fs_dpgm_model.phi[i]
    latent_feature = torch.log(dpgm_phi @ fs_pgds.fs_dpgm_model.lam_kk + 0.1)
    im = axs[i].imshow(latent_feature, cmap='jet')
    axs[i].set_title(f'M_skc:Interval {i+1}')
    cbar = plt.colorbar(im, ax = axs[i], shrink=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Complex case

# %%
# complex case
# generate sysnthetic data
T = 1000
S = 5
high_value = 10
sys = torch.zeros(T,100,100)
# interval 1
sys[0:50, 0:20, 0:20] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[50:100, 80:100, 80:100] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[100:150, 0:20, 0:20] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[150:200, 80:100, 80:100] = torch.poisson(high_value * torch.ones(50, 20, 20))
# interval 2 
sys[200:250, 20:40, 20:40] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[250:300, 60:80, 60:80] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[300:350, 20:40, 20:40] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[350:400, 60:80, 60:80] = torch.poisson(high_value * torch.ones(50, 20, 20))
# interval 3
sys[400:450, 0:20,0:20] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[400:450, 20:40,20:40] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[450:500, 60:80,60:80] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[450:500, 80:100,80:100] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[500:550, 0:20,0:20] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[500:550, 20:40,20:40] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[550:600, 60:80,60:80] = torch.poisson(high_value * torch.ones(50, 20, 20))
sys[550:600, 80:100,80:100] = torch.poisson(high_value * torch.ones(50, 20, 20))
# interval 4
sys[600:800, 20:40,20:40] = torch.poisson(high_value * torch.ones(200, 20, 20))
sys[600:800, 60:80,60:80] = torch.poisson(high_value * torch.ones(200, 20, 20))
# interval 5
sys[800:1000, 40:60, 40:60] = torch.poisson(high_value * torch.ones(200, 20, 20))

# %%
# run model
burnin = 60
maxiter = 20
params = {
'tau': 1.,
'alpha0': 10.,
'epsilon_lam': 1.,
'stationary': True,
'data' : sys,
'K' : 50, # latent components
'S' : 200 # sub-intervals
}

fs_pgds = FS_PGDS_tensor(**params)
esti_steady = []
transition_steady = []
# phi should be a list
fs_pgds.phi[0][:,:] = 0.
fs_pgds.phi[0][0:20,0:10] = 1/20
fs_pgds.phi[0][20:40,10:20] = 1/20
fs_pgds.phi[0][40:60,20:30] = 1/20
fs_pgds.phi[0][60:80,30:40] = 1/20
fs_pgds.phi[0][80:100,40:50] = 1/20
fs_pgds.phi[1][:,:] = 0.
fs_pgds.phi[1][0:20,0:10] = 1/20
fs_pgds.phi[1][20:40,10:20] = 1/20
fs_pgds.phi[1][40:60,20:30] = 1/20
fs_pgds.phi[1][60:80,30:40] = 1/20
fs_pgds.phi[1][80:100,40:50] = 1/20

initial_pi = torch.zeros(50,50)
initial_pi[0:10, 0:10] = 1/10
initial_pi[10:20, 10:20] = 1/10
initial_pi[20:30, 20:30] = 1/10
initial_pi[30:40, 30:40] = 1/10
initial_pi[40:50, 40:50] = 1/10
fs_pgds.pi  = torch.tile(initial_pi, (params['S'],1,1)) # torch.tile的对象必须是tensor
fs_pgds.pit = torch.tile(initial_pi, (T,1,1))
fs_pgds.D   = torch.ones(fs_pgds.K, fs_pgds.K)*10
# to induce m_skc to be sampled toward specfied pattern
selected_communities = torch.randint(low=0, high=50, size=(5,))
fs_pgds.fs_dpgm_model.phi = torch.ones_like(fs_pgds.fs_dpgm_model.phi) * fs_pgds.eps
fs_pgds.fs_dpgm_model.phi_o = torch.ones_like(fs_pgds.fs_dpgm_model.phi_o) * fs_pgds.eps
fs_pgds.fs_dpgm_model.phi[:,:,selected_communities] = 1.
fs_pgds.fs_dpgm_model.phi_o[:,selected_communities] = 1. 

for iter in tqdm(range(burnin+maxiter)):
    fs_pgds.sample_n()
    fs_pgds.sample_l()
    fs_pgds.sample_the()
    fs_pgds.sample_lam()
    fs_pgds.sample_delt()
    fs_pgds.sample_beta()
    fs_pgds.sample_phi()
    fs_pgds.sample_pi()
    fs_pgds.sample_eta()
    fs_pgds.sample_A()
    fs_pgds.sample_dpgm()

    if iter > burnin:
        transition_steady.append(fs_pgds.pi.clone())
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# sample_n took 253.4214 seconds
# sample_l took 17.3413 seconds
# sample_the took 0.0085 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0184 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 1.7131 seconds
# sample_pi took 1.4171 seconds
# sample_eta took 0.0041 seconds
# Sum over self.A:  tensor(35726)
# sample_A took 104.7941 seconds
# sample_dpgm took 3.0133 seconds
# sample_n took 252.0767 seconds
# sample_l took 19.1122 seconds
# sample_the took 0.0068 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0176 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 1.7083 seconds
# sample_pi took 1.1242 seconds
# sample_eta took 0.0040 seconds
# Sum over self.A:  tensor(127106)
# sample_A took 112.2457 seconds
# sample_dpgm took 4.1473 seconds
# sample_n took 264.6692 seconds
# sample_l took 26.1364 seconds
# sample_the took 0.0099 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0184 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 1.4081 seconds
# sample_pi took 1.1346 seconds
# sample_eta took 0.0046 seconds
# Sum over self.A:  tensor(334371)
# sample_A took 139.7978 seconds
# sample_dpgm took 5.8536 seconds
# sample_n took 255.9079 seconds
# sample_l took 24.7101 seconds
# sample_the took 0.0162 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0184 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 1.2245 seconds
# sample_pi took 1.1141 seconds
# sample_eta took 0.0038 seconds
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
