# %%
import _4_pgds_info_rate
import matplotlib.pyplot as plt
import numpy as np
import torch
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 1,
'burin': 600,
'maxiter': 400,
'seed': 1234
}

model, transition_collection, nglogll_collection = _4_pgds_info_rate.main(**params)

# %%
import pickle

with open('icew100_nglogll_mat_pgds_eps01_40_20.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
import pickle 

with open('nglogll_matrix_pgds_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 55,
'S': 1,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1233
}

model, transition_collection, nglogll_collection = _4_pgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 2.2897 seconds
# sample_l took 8.3659 seconds
# sample_the took 0.0041 seconds
# sample_delt took 0.0005 seconds
# sample_beta took 0.0002 seconds
# sample_xi_nu took 0.0029 seconds
# sample_phi took 0.0170 seconds
# sample_pi took 0.0057 seconds
# sample_n took 2.2040 seconds
# sample_l took 7.1029 seconds
# sample_the took 0.0031 seconds
# sample_delt took 0.0004 seconds
# sample_beta took 0.0002 seconds
# sample_xi_nu took 0.0066 seconds
# sample_phi took 0.0163 seconds
# sample_pi took 0.0061 seconds
# sample_n took 2.2626 seconds
# sample_l took 6.5998 seconds
# sample_the took 0.0039 seconds
# sample_delt took 0.0004 seconds
# sample_beta took 0.0002 seconds
# sample_xi_nu took 0.0067 seconds
# sample_phi took 0.0156 seconds
# sample_pi took 0.0060 seconds
# sample_n took 2.4955 seconds
# sample_l took 6.3137 seconds
# sample_the took 0.0035 seconds
# sample_delt took 0.0004 seconds
# sample_beta took 0.0002 seconds
# ...

# %% [markdown]
# K=50

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# K = 55

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# K = 70

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
import pickle

with open('icew_nglogll_tensor_pgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
