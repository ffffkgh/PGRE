# %%
import _7_gs_pgds_info_rate
import matplotlib.pyplot as plt
import numpy as np
import torch
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 6,
'burin': 600,
'maxiter': 400,
'seed': 1234
}

model, transition_collection, nglogll_collection = _7_gs_pgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 2.3078 seconds
# sample_l took 9.1696 seconds
# sample_the took 0.0040 seconds
# sample_delt took 0.0004 seconds
# sample_phi took 0.0114 seconds
# sample_pi took 0.0582 seconds
# sample_eta took 0.0008 seconds
# sample_tilde_lskk took 0.0676 seconds
# sample_Z took 3.5262 seconds
# sample_D took 0.0027 seconds
# sample_dpgm took 13.4312 seconds
# sample_n took 2.9285 seconds
# sample_l took 7.9555 seconds
# sample_the took 0.0054 seconds
# sample_delt took 0.0005 seconds
# sample_phi took 0.0121 seconds
# sample_pi took 0.0591 seconds
# sample_eta took 0.0010 seconds
# sample_tilde_lskk took 0.1025 seconds
# sample_Z took 3.9952 seconds
# sample_D took 0.0028 seconds
# sample_dpgm took 11.3895 seconds
# sample_n took 2.8251 seconds
# sample_l took 7.0775 seconds
# sample_the took 0.0058 seconds
# sample_delt took 0.0005 seconds
# sample_phi took 0.0115 seconds
# sample_pi took 0.0597 seconds
# sample_eta took 0.0008 seconds
# ...

# %%
import pickle 

with open('icew100_nglogll_matrix_gs_pgds_eps01_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'GS-PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 55,
'S': 5,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1233
}

model, transition_collection, nglogll_collection = _7_gs_pgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 10.9593 seconds
# sample_l took 19.5611 seconds
# sample_the took 0.0038 seconds
# sample_delt took 0.0004 seconds
# sample_phi took 0.0194 seconds
# sample_pi took 0.0387 seconds
# sample_eta took 0.0007 seconds
# sample_tilde_lskk took 0.0354 seconds
# sample_Z took 1.4258 seconds
# sample_D took 0.0020 seconds
# sample_dpgm took 6.7516 seconds
# sample_n took 2.3639 seconds
# sample_l took 6.8767 seconds
# sample_the took 0.0037 seconds
# sample_delt took 0.0004 seconds
# sample_phi took 0.0193 seconds
# sample_pi took 0.0389 seconds
# sample_eta took 0.0007 seconds
# sample_tilde_lskk took 0.0841 seconds
# sample_Z took 1.9682 seconds
# sample_D took 0.0016 seconds
# sample_dpgm took 10.3711 seconds
# sample_n took 11.0918 seconds
# sample_l took 22.7780 seconds
# sample_the took 0.0298 seconds
# sample_delt took 0.0009 seconds
# sample_phi took 0.2340 seconds
# sample_pi took 0.2469 seconds
# ...

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'GS_PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
with open('icew_nglogll_tensor_gs_pgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %% [markdown]
# K = 55

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'GS_PGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
