# %%
import _2_fs_nbrgds_info_rate
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

# %% [markdown]
# # Matrix

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_preprocessed.npz',
'K': 70,
'S': 6,
'burin': 600,
'maxiter': 400,
'seed': 1234
}

model, transition_collection, nglogll_collection = _2_fs_nbrgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 4.1630 seconds
# sample_h took 1.2233 seconds
# sample_aux_h took 9.9229 seconds
# sample_the took 0.0057 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0012 seconds
# sample_g took 0.0037 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0125 seconds
# sample_pi took 0.0670 seconds
# sample_eta took 0.0013 seconds
# Sum over self.A:  tensor(32589)
# sample_A took 20.2711 seconds
# sample_dpgm took 0.1872 seconds
# sample_n took 3.6145 seconds
# sample_h took 1.2565 seconds
# sample_aux_h took 7.8706 seconds
# sample_the took 0.0077 seconds
# sample_lam took 0.0005 seconds
# sample_delt took 0.0283 seconds
# sample_g took 0.0047 seconds
# sample_gam took 0.0003 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0244 seconds
# sample_pi took 0.0817 seconds
# sample_eta took 0.0012 seconds
# Sum over self.A:  tensor(10231)
# sample_A took 12.4418 seconds
# ...

# %%
import pickle

with open('icew100_nglogll_mat_fs_nbrgds_eps01_40_20.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
import pickle 

with open('nglogll_matrix_fs_nbrgds_eps0_600_400.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(nglogll_collection['Training'], color = 'blue', label = 'GS-PRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
# %matplotlib inline
fig, axs = plt.subplots(50, 2, figsize = (16,200))
for i, ax in enumerate(axs.flatten()):
    ax.plot(model.the.T[i])
    ax.set_title('Component {}'.format(i+1))
plt.show()

# %% [markdown]
# # Tensor

# %%
params = {
'data_dir': '/home/HuangRui/PointProcess/NodeGroup/data/icews_tensor_reconstruct_3001010_same_src_tar.npz',
'K': 50,
'S': 5,
'burin': 800,
'maxiter': 200,
'type': 'tensor',
'seed': 1234
}

model, transition_collection, nglogll_collection = _2_fs_nbrgds_info_rate.main(**params)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sample_n took 3.4190 seconds
# sample_h took 0.9775 seconds
# sample_aux_h took 6.8171 seconds
# sample_the took 0.0027 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0004 seconds
# sample_g took 0.0027 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0001 seconds
# sample_phi took 0.0159 seconds
# sample_pi took 0.0347 seconds
# sample_eta took 0.0006 seconds
# Sum over self.A:  tensor(17635)
# sample_A took 8.1101 seconds
# sample_dpgm took 0.0930 seconds
# sample_n took 3.3366 seconds
# sample_h took 0.6692 seconds
# sample_aux_h took 4.7987 seconds
# sample_the took 0.0033 seconds
# sample_lam took 0.0004 seconds
# sample_delt took 0.0005 seconds
# sample_g took 0.0033 seconds
# sample_gam took 0.0002 seconds
# sample_beta took 0.0002 seconds
# sample_phi took 0.0158 seconds
# sample_pi took 0.0348 seconds
# sample_eta took 0.0006 seconds
# Sum over self.A:  tensor(6495)
# sample_A took 4.9048 seconds
# ...

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS-NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %%
import pickle

with open('icew_nglogll_tensor_fs_nbrgds_eps01_800_200.pkl', 'wb') as f:
    pickle.dump(nglogll_collection, f)

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS-NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary, $\epsilon_0^{(\theta)}=0.1$, K=30

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS-NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()

# %% [markdown]
# stationary, $\epsilon_0^{(\theta)}=0.1$, K=80, icews_tensor_reconstruct_3001010.npz

# %%
# %matplotlib inline
plt.plot(np.arange(1,1001), nglogll_collection['Training'], color = 'blue', label = 'FS-NBRGDS')
plt.xscale('log')
plt.legend()
plt.title('Negative log likelihood over training period')
plt.show()
